# %% [markdown]
# Introduction to python programming

# %%
print("Hello World")
print("Welcome to PDA")
# Out:
# Hello World
# Welcome to PDA

# %% [markdown]
# Indentation

# %%
print("I have no indentation")
print("    I have indentation")
# Out:
# I have no indentation
#     I have indentation

# %% [markdown]
# Taking input

# %%
name = input("Enter the name:")
print("Hello", name, "Welcome!")
# Out:
# Enter the name: rakchu
# Hello rakchu Welcome!

# %% [raw]
# Printing output

# %%
s = "ABC"
age =25
P = "India"
print(s,age, P)
# Out:
# ABC 25 India

# %% [markdown]
# Taking multiple inputs

# %%
x,y,z = input("Enter three numbers:").split()
print("Total number of students:",x)
print("Total number of boys:",y)
print("Total number of girls:",z)
# Out:
# Enter three numbers: 50 26 24
# Total number of students: 50
# Total number of boys: 26
# Total number of girls: 24

# %% [markdown]
# python variable

# %%
x = 55.7
s = "hello"
print(x)
print(s)
# Out:
# 55.7
# hello

# %% [markdown]
# type casting a varible

# %%
i = int(x)
S1 = str(x)
print(i)
print(S1)
# Out:
# 55
# 55.7

# %% [markdown]
# getting type of varible

# %%
n1 = 55
n2 = 55.6
n3 = "Hello"
n4 = [1,2,3]
n5 = {"a":1,"b":2,"c":3}
n6 = True
print(type (n1))
print(type (n2))
print(type (n3))
print(type (n4))
print(type (n5))
print(type (bool))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'type'>

# %% [markdown]
# python data type
# numeric data type

# %%
a=5
print(type(a))
b=5.2
print(type(b))
c = 5 + 2j
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# Sequence data type

# %%
s = "Welcome to PDA"
print(type(s))
print(s)
print(s[1])
print(s[-1])
# Out:
# <class 'str'>
# Welcome to PDA
# e
# A

# %% [markdown]
# list

# %%
a = []
print(type(a))
b=[1,2,3]
print(b)
c=[1,2.3,"A","Apple"]
print(c)
print(b[0])
print(b[1])
print(b[-1])
print(b[-2])
# Out:
# <class 'list'>
# [1, 2, 3]
# [1, 2.3, 'A', 'Apple']
# 1
# 2
# 3
# 2

# %% [markdown]
# tuples

# %%
t1 = ("class","for","PDA")
t2 = (1,2,3,4,5)
print(type(t1))
print(t2)
print(t1[-1])
print(t2[2])
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)
# PDA
# 3

# %% [markdown]
# boolean

# %%
print(type(False))
print(type(True))
if 1 :
    print("1 is true")
else:
    print("0 is false")
# Out:
# <class 'bool'>
# <class 'bool'>
# 1 is true

# %% [markdown]
# sets

# %%
s1 = ()
s2 = ("Beautiful day")
s3 = set["A","B","C"]
print(type(s1))
print(s2)
for s in s3:
    print(s, end="")
# Out:
# <class 'tuple'>
# Beautiful day
# *set['A', 'B', 'C']

# %% [markdown]
# dictionary

# %%
d1 = {}
d2 = {"a":1, "b":2,"c":3}
d3 = {1:"a",2:"b",3:"c"}
print(d3[1])
# Out:
# a

# %% [markdown]
# #TYPECONVERSION
# implicit type conversion

# %%
x = 10
y = 10.6
z = x+y
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# explicit type conversion

# %%
a = "52.6"
b = float(a)
print(type(a))
print(type(b))

s = "Hello world"
t = tuple(s)
u = list(s)
v = set(s)

print(type (s))
print(type(t))
print(type(u))
print(type(v))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'tuple'>
# <class 'list'>
# <class 'set'>

# %% [markdown]
# OPERATOR

# %% [markdown]
# arithmetic operators

# %%
a = 17
b = 5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 22
# 12
# 85
# 3.4
# 3
# 2
# 1419857

# %% [markdown]
# comparison operators

# %%
a=7
b=5
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a!=b)
print(a==b)
# Out:
# True
# False
# True
# False
# True
# False

# %% [markdown]
# logical operator

# %%
a=True
b=False
print(a and b)
print(a or b)
print(not b)
# Out:
# False
# True
# True

# %% [markdown]
# bitwise operator

# %%
a=5
b=2
print(a&b)
print(a/b)
print(~a)
print(a^b)
print(a>>2)
print(a<<2)
# Out:
# 0
# 2.5
# -6
# 7
# 1
# 20

# %% [markdown]
# Assignment operator

# %%
a=10
b=2
a+=b
print(a)
a-=b
print(a)
a>>=b
print(a)
a<<=b
print(a)
# Out:
# 12
# 10
# 2
# 8

# %% [markdown]
# identify operators

# %%
a=10
b=5
c=a
print(c is a)
print(c is not b)
# Out:
# True
# True

# %% [markdown]
# ternary operator

# %%
min=a if a<b else b
print(min)
# Out:
# 5

# %% [markdown]
# membership operator

# %%
x=24
y=20
list1=[10,20,30,40]
if x not in list1:
    print("x not in list1")
if y in list1: 
    print("y is in list1")
# Out:
# x not in list1
# y is in list1

# %% [markdown]
# questions(find output)

# %%
name="Alex"
age=0
if(name=="Alex"or name=="John" and age>=2):
    print("Welcome")
else:
    print("Bye")
# Out:
# Welcome

# %% [markdown]
# if statement

# %%
a=10
if a>5:
    print("a is greater than 5")
# Out:
# a is greater than 5

# %% [markdown]
# if else statement

# %%
a=3
if a>5:
    print("a is greater than 5")
else:
    print("a is not greater than 5")
# Out:
# a is not greater than 5

# %% [markdown]
# if elif else statement

# %%
marks=85
if marks>=90:
    print("Grade A") 
elif marks>=60:
    print("Grade B")
else:
    print("Grade C")
# Out:
# Grade B

# %% [markdown]
# short hand if else

# %%
x = 10
y = 20
print("x is greater") if x > y else print("y is greater")
# Out:
# y is greater

# %%
#nested if else
num = 10
if num > 0:
    if num % 2 == 0: 
        print("Positive Even number")
    else:
        print("Positive Odd number")
else:
    print("Negative number")
# Out:
# Positive Even number

# %% [markdown]
# #looping statement
# #for loop

# %%
 for i in range(1, 6): 
     print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# break

# %%
for i in range(1,6):
    if i == 3:
        break 
    print(i)
# Out:
# 1
# 2

# %% [markdown]
# continue statement

# %%
for i in range(1,6):
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %% [markdown]
# pass statement

# %%
for i in range(5):
    if i== 3:
        pass
        print(i)
# Out:
# 3

# %% [markdown]
# match case

# %%
day = 2
match day:
    case 1:
        print("Monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wednesday")
    case _:
        print("Invalid day")
# Out:
# Tuesday

# %% [raw]
# ternary if else

# %%
n = 7
result = "Even" if n%2==0 else "odd"
print(result)
# Out:
# odd
